# %% [markdown]
# # Iterative Prompt Development

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

client = OpenAI()

def get_completion(prompt: str, model: str = "gpt-4.1-mini") -> str:
    response = client.responses.create(
        model=model,
        input=prompt
    )
    return response.output_text

# %% [markdown]
# ## Generate a marketing product description from a product fact sheet

# %%
fact_sheet_chair = """
OVERVIEW
- Part of a beautiful family of mid-century inspired office furniture, 
including filing cabinets, desks, bookcases, meeting tables, and more.
- Several options of shell color and base finishes.
- Available with plastic back and front upholstery (SWC-100) 
or full upholstery (SWC-110) in 10 fabric and 6 leather options.
- Base finish options are: stainless steel, matte black, 
gloss white, or chrome.
- Chair is available with or without armrests.
- Suitable for home or business settings.
- Qualified for contract use.

CONSTRUCTION
- 5-wheel plastic coated aluminum base.
- Pneumatic chair adjust for easy raise/lower action.

DIMENSIONS
- WIDTH 53 CM | 20.87”
- DEPTH 51 CM | 20.08”
- HEIGHT 80 CM | 31.50”
- SEAT HEIGHT 44 CM | 17.32”
- SEAT DEPTH 41 CM | 16.14”

OPTIONS
- Soft or hard-floor caster options.
- Two choices of seat foam densities: 
 medium (1.8 lb/ft3) or high (2.8 lb/ft3)
- Armless or 8 position PU armrests 

MATERIALS
SHELL BASE GLIDER
- Cast Aluminum with modified nylon PA6/PA66 coating.
- Shell thickness: 10 mm.
SEAT
- HD36 foam

COUNTRY OF ORIGIN
- Italy
"""

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Elevate your workspace with this elegant mid-century inspired office chair, designed to blend seamlessly with our stunning family of filing cabinets, desks, bookcases, and meeting tables. Crafted in Italy with impeccable attention to detail, this chair offers a perfect balance of style and functionality for both home and business environments.
#
# Featuring a durable 5-wheel plastic-coated aluminum base with a smooth pneumatic lift, adjusting your seating height is effortless. Choose from a variety of shell colors and base finishes including stainless steel, matte black, gloss white, or chrome, to perfectly complement your office décor.
#
# Customize your comfort with options such as plastic back and front upholstery (SWC-100) or full upholstery (SWC-110), available in 10 premium fabrics and 6 luxurious leather styles. The chair also offers armless or 8-position PU armrests, soft or hard-floor caster options, and two seat foam densities—medium or high—for personalized support.
#
# With compact dimensions (53 cm W x 51 cm D x 80 cm H) and a sturdy cast aluminum shell enhanced by a nylon coating, this chair combines mid-century charm with modern durability. Qualified for contract use, it’s an ideal choice for professionals who value both design and long-term performance.
#
# Upgrade your office seating with a chair that embodies timeless mid-century design, exceptional comfort, and versatile customization options—all crafted with Italian excellence.

# %% [markdown]
# ## Issue 1: The text is too long
# - Limit the number of words/sentences/characters.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Mid-century inspired office chair with customizable upholstery, base finishes, and armrest options. Features a durable cast aluminum shell, pneumatic height adjustment, and soft or hard-floor casters. Stylish, comfortable, and built for home or contract use. Made in Italy.

# %%
len(response.split())
# Out:
# 38

# %% [markdown]
# ## Issue 2. Text focuses on the wrong details
# - Ask it to focus on the aspects that are relevant to the intended audience.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Crafted in Italy, this mid-century inspired office chair features a 10mm thick cast aluminum shell coated with modified nylon PA6/PA66. It includes an HD36 foam seat, a 5-wheel plastic-coated aluminum base, pneumatic height adjustment, and customizable upholstery and armrest options for contract use.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# This mid-century inspired office chair features a 10 mm thick cast aluminum shell with PA6/PA66 nylon coating, a 5-wheel plastic-coated aluminum base, and HD36 foam seat. Options include multiple upholstery, base finishes, caster types, and armrest configurations. Made in Italy. Product ID: SWC-100, SWC-110

# %% [markdown]
# ## Issue 3. Description needs a table of dimensions
# - Ask it to extract information and organize it in a table.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

After the description, include a table that gives the 
product's dimensions. The table should have two columns.
In the first column include the name of the dimension. 
In the second column include the measurements in inches only.

Give the table the title 'Product Dimensions'.

Format everything as HTML that can be used in a website. 
Place the description in a <div> element.

Technical specifications: ```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)
# Out:
# <div>
#   This mid-century inspired office chair is part of an extensive furniture collection that includes filing cabinets, desks, bookcases, and meeting tables. Designed with versatility in mind, it is suitable for both home and business environments and qualified for contract use. The chair construction features a robust 5-wheel base made from cast aluminum, enhanced with a plastic-coated nylon (PA6/PA66) for durability and smooth mobility. The shell of the chair maintains a 10 mm thickness, ensuring a solid, long-lasting form.
#
#   Upholstery options cater to a variety of aesthetic preferences, offering choices between plastic-backed front upholstery (SWC-100) or fully upholstered styles (SWC-110) available in 10 fabric and 6 leather options. The base finishes include stainless steel, matte black, gloss white, or chrome, allowing customization to match different interior designs.
#
#   Ergonomics are supported by pneumatic chair adjustment for easy height modification and optional armrests with 8-position PU pads or an armless configuration. The seating uses high-density HD36 foam with selectable medium (1.8 lb/ft³) or high (2.8 lb/ft³) density foam cushions for long-lasting comfort.
#
#   Additional options include soft or hard-floor caster types to suit various flooring surfaces. The chair is manufactured in Italy, combining craftsmanship with premium materials to meet professional standards.
#
#   Product ID: SWC-100, SWC-110
# </div>
#
# <table>
#   <caption><strong>Product Dimensions</strong></caption>
#   <tbody>
#     <tr>
#       <td>Width</td>
#       <td>20.87”</td>
#     </tr>
#     <tr>
#       <td>Depth</td>
#       <td>20.08”</td>
#     </tr>
#     <tr>
#       <td>Height</td>
#       <td>31.50”</td>
#     </tr>
#     <tr>
#       <td>Seat Height</td>
#       <td>17.32”</td>
#     </tr>
#     <tr>
#       <td>Seat Depth</td>
#       <td>16.14”</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Load Python libraries to view HTML

# %%
from IPython.display import display, HTML

# %%
display(HTML(response))
# Out:
# <div>
#   This mid-century inspired office chair is part of an extensive furniture collection that includes filing cabinets, desks, bookcases, and meeting tables. Designed with versatility in mind, it is suitable for both home and business environments and qualified for contract use. The chair construction features a robust 5-wheel base made from cast aluminum, enhanced with a plastic-coated nylon (PA6/PA66) for durability and smooth mobility. The shell of the chair maintains a 10 mm thickness, ensuring a solid, long-lasting form.
#
#   Upholstery options cater to a variety of aesthetic preferences, offering choices between plastic-backed front upholstery (SWC-100) or fully upholstered styles (SWC-110) available in 10 fabric and 6 leather options. The base finishes include stainless steel, matte black, gloss white, or chrome, allowing customization to match different interior designs.
#
#   Ergonomics are supported by pneumatic chair adjustment for easy height modification and optional armrests with 8-position PU pads or an armless configuration. The seating uses high-density HD36 foam with selectable medium (1.8 lb/ft³) or high (2.8 lb/ft³) density foam cushions for long-lasting comfort.
#
#   Additional options include soft or hard-floor caster types to suit various flooring surfaces. The chair is manufactured in Italy, combining craftsmanship with premium materials to meet professional standards.
#
#   Product ID: SWC-100, SWC-110
# </div>
#
# <table>
#   <caption><strong>Product Dimensions</strong></caption>
#   <tbody>
#     <tr>
#       <td>Width</td>
#       <td>20.87”</td>
#     </tr>
#     <tr>
#       <td>Depth</td>
#       <td>20.08”</td>
#     </tr>
#     <tr>
#       <td>Height</td>
#       <td>31.50”</td>
#     </tr>
#     <tr>
#       <td>Seat Height</td>
#       <td>17.32”</td>
#     </tr>
#     <tr>
#       <td>Seat Depth</td>
#       <td>16.14”</td>
#     </tr>
#   </tbody>
# </table>
